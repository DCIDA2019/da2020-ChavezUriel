# %%
import math
import matplotlib.pyplot as plt

veli=2  #condiciones iniciales
posi=0

w0=3  #frecuencia angular=sqrt(g/l)

it=1000  #número de iteraciones
ti=0  #tiempo inicial
tf=10  #tiempo final
h=(tf-ti)/(it+1)  #tamaño de paso

pos=[0]*it  #arreglo para guardar posición
vel=[0]*it  #arreglo para guardar velocidad
posreal=[0]*it
velreal=[0]*it

t=[0]*it

pos[0]=posi  #aplicación de condiciones iniciales
vel[0]=veli
posreal[0]=posi
velreal[0]=veli

# %%
for i in range(0,it-1):
    pos[i+1]=pos[i]+h*vel[i]
    vel[i+1]=vel[i]+h*(-w0**2*pos[i])
    t[i+1]=t[i]+h
    posreal[i+1]=2/w0*np.sin(w0*t[i+1])
    velreal[i+1]=2*np.cos(w0*t[i+1])

# %%
plt.plot(t,pos,'b',t,posreal,'r--')
# Out:
# [<matplotlib.lines.Line2D at 0x7f775db0cdd0>,
#  <matplotlib.lines.Line2D at 0x7f775db0cf90>]

# %%
plt.plot(t,vel,'b',t,velreal,'r--')
# Out:
# [<matplotlib.lines.Line2D at 0x7f775dbded50>,
#  <matplotlib.lines.Line2D at 0x7f775dbde690>]
